# %% [markdown]
# ## ETCD LAB
#
# A distributed, reliable key-value store for the most critical data of a distributed system.
# Homepage: https://etcd.io/
#
# Key features:
#
# - Simple: well-defined, user-facing API (gRPC)
# - Secure: automatic TLS with optional client cert authentication
# - Fast: benchmarked 10,000 writes/sec
# - Reliable: properly distributed using Raft
#
#
# There are two major use cases: concurrency control in the distributed system and application configuration store. For example, CoreOS Container Linux uses etcd to achieve a global semaphore to avoid that all nodes in the cluster rebooting at the same time. Also, Kubernetes use etcd for their configuration store.
#
# During this lab we will be using etcd3 python client.
# Homepage: https://pypi.org/project/etcd3/

# %% [markdown]
# Etcd credentials are shared on the slack channel: https://join.slack.com/t/ibm-agh-labs/shared_invite/zt-e8xfjgtd-8IDWmn912qPOflbM1yk6~Q
#
# Please copy & paste them into the cell below:

# %%
etcdCreds = {}  # copy and paste etcd credentials provided on the Slack channel here

# %%
# !pip install etcd3
# Out:
# Requirement already satisfied: etcd3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.12.0)
# Requirement already satisfied: grpcio>=1.27.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from etcd3) (1.29.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from etcd3) (3.6.1)
# Requirement already satisfied: tenacity>=6.1.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from etcd3) (6.2.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from etcd3) (1.12.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python36/lib/python3.6/site-packages (from protobuf>=3.6.1->etcd3) (40.8.0)

# %% [markdown]
# ### How to connect to etcd using certyficate (part 1: prepare file with certificate)

# %%
import base64
import tempfile

etcdHost = etcdCreds["connection"]["grpc"]["hosts"][0]["hostname"]
etcdPort = etcdCreds["connection"]["grpc"]["hosts"][0]["port"]
etcdUser = etcdCreds["connection"]["grpc"]["authentication"]["username"]
etcdPasswd = etcdCreds["connection"]["grpc"]["authentication"]["password"]
etcdCertBase64 = etcdCreds["connection"]["grpc"]["certificate"]["certificate_base64"]
                           
etcdCertDecoded = base64.b64decode(etcdCertBase64)
etcdCertPath = "{}/{}.cert".format(tempfile.gettempdir(), etcdUser)
                           
with open(etcdCertPath, 'wb') as f:
    f.write(etcdCertDecoded)

print(etcdCertPath)
# Out:
# /home/dsxuser/.tmp/ibm_cloud_f59f3a7b_7578_4cf8_ba20_6df3b352ab46.cert

# %% [markdown]
# ### Short Lab description
#
# During the lab we will simulate system that keeps track of logged users
# - All users will be stored under parent key (path): /logged_users
# - Each user will be represented by key value pair
#     - key /logged_users/name_of_the_user
#     - value hostname of the machine (e.g. name_of_the_user-hostname)

# %% [markdown]
# ### How to connect to etcd using certyficate (part 2: create client)

# %%
import etcd3

etcd = etcd3.client(
    host=etcdHost,
    port=etcdPort,
    user=etcdUser,
    password=etcdPasswd,
    ca_cert=etcdCertPath
)

cfgRoot='/logged_users'

# %% [markdown]
# ### Task 1 : Fetch username and hostname
#
# define two variables
# - username name of the logged user (tip: use getpass library)
# - hostname hostname of your mcomputer (tip: use socket library)

# %%
import getpass
import socket

username = "kustra"  # You can put your name here, while this code is run in the container and user name would be same for all students
hostname = socket.gethostname()

userKey='{}/{}'.format(cfgRoot, username)
userKey, '->', hostname

etcd.put(userKey, hostname)
# Out:
# header {
#   cluster_id: 17394822126184162018
#   member_id: 17586574424884576738
#   revision: 354954
#   raft_term: 3204
# }

# %%
value, metadata = etcd.get('/logged_users/kustra')
print(value)
print(metadata.key)
print(metadata.version)
# Out:
# b'notebook-0b34268899e14795b60b6d36d0883ae1-576b4b5d8d-w62xc'
# b'/logged_users/kustra'
# 2

# %% [markdown]
# ### Task 2 : Register number of users
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# for all names in table fixedUsers register the appropriate key value pairs

# %%
fixed_users = [
    'Adam',
    'Borys',
    'Cezary',
    'Damian',
    'Emil',
    'Filip',
    'Gustaw',
    'Henryk',
    'Ignacy',
    'Jacek',
    'Kamil',
    'Leon',
    'Marek',
    'Norbert',
    'Oskar',
    'Patryk',
    'Rafał',
    'Stefan',
    'Tadeusz'
]

for user in fixed_users:
    user_key='{}/{}'.format(cfgRoot, user)
    hostname = socket.gethostname()
    print(user_key)
    etcd.put(user_key,hostname)
# Out:
# /logged_users/Adam
# /logged_users/Borys
# /logged_users/Cezary
# /logged_users/Damian
# /logged_users/Emil
# /logged_users/Filip
# /logged_users/Gustaw
# /logged_users/Henryk
# /logged_users/Ignacy
# /logged_users/Jacek
# /logged_users/Kamil
# /logged_users/Leon
# /logged_users/Marek
# /logged_users/Norbert
# /logged_users/Oskar
# /logged_users/Patryk
# /logged_users/Rafał
# /logged_users/Stefan
# /logged_users/Tadeusz

# %% [markdown]
# ### Task 3: List all users
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# List all registered user (tip: use common prefix)

# %%
results = etcd.get_prefix(cfgRoot)
{m.key : v for v, m in results}
# Out:
# {b'/logged_users': b'/logged_users/Tadeusz - Registered',
#  b'/logged_users//logged_users': b'notebook-438cad81f4974877a0c254a6d6ff0145-58f95b7948-zfpxd',
#  b'/logged_users/0': b'Adam',
#  b'/logged_users/1': b'Borys',
#  b'/logged_users/10': b'Kamil',
#  b'/logged_users/11': b'Leon',
#  b'/logged_users/12': b'Marek',
#  b'/logged_users/13': b'Norbert',
#  b'/logged_users/14': b'Oskar',
#  b'/logged_users/15': b'Patryk',
#  b'/logged_users/16': b'Rafa\xc5\x82',
#  b'/logged_users/17': b'Stefan',
#  b'/logged_users/18': b'Tadeusz',
#  b'/logged_users/2': b'Cezary',
#  b'/logged_users/3': b'Damian',
#  b'/logged_users/4': b'Emil',
#  b'/logged_users/5': b'Filip',
#  b'/logged_users/6': b'Gustaw',
#  b'/logged_users/7': b'Henryk',
#  b'/logged_users/8': b'Ignacy',
#  b'/logged_users/9': b'Jacek',
#  b'/logged_users/Adam': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Andrii': b'notebook-75760867122b4b86a5bbcd2f5ccc321b-66fd799d96-dc62c',
#  b'/logged_users/Borys': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Cezary': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Damian': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Dawid/Adam': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Borys': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Cezary': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Damian': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Emil': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Filip': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Gustaw': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Henryk': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Ignacy': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Jacek': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Kamil': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Leon': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Marek': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Norbert': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Oskar': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Patryk': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Rafa\xc5\x82': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Stefan': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Dawid/Tadeusz': b'notebook-a44d382faeed459cb058c7e5432b8e8c-c5c54fd59-bxlrd',
#  b'/logged_users/Emil': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Filip': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Filip2': b'testmessage3',
#  b'/logged_users/Gaben/Adam': b'test_9',
#  b'/logged_users/Gaben/Borys': b'Borys-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Cezary': b'Cezary-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Damian': b'Damian-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Emil': b'Emil-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Filip': b'Filip-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Gustaw': b'Gustaw-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Henryk': b'Henryk-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Ignacy': b'Ignacy-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Jacek': b'Jacek-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Kamil': b'Kamil-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Leon': b'Leon-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Marek': b'Marek-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Norbert': b'Norbert-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Oskar': b'Oskar-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Patryk': b'Patryk-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Rafa\xc5\x82': b'Rafa\xc5\x82-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Stefan': b'Stefan-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/Tadeusz': b'Tadeusz-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8',
#  b'/logged_users/Gaben/errors': b'condition failed',
#  b'/logged_users/Gaben/mama': b'kochana',
#  b'/logged_users/GargasJan': b'notebook-a7823551d9b84fd3b085958036c5f597-d469f8875-ltf7p',
#  b'/logged_users/Gustaw': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Henryk': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Hubert/Adam': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Borys': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Cezary': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Damian': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Emil': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Filip': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Gustaw': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Henryk': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Ignacy': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Jacek': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Kamil': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Leon': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Marek': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Norbert': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Oskar': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Patryk': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Rafa\xc5\x82': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Stefan': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Hubert/Tadeusz': b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd',
#  b'/logged_users/Ignacy': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Jacek': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Jakub Mysliwiec': b'notebook-condafree1py3690879dede28a40ed88e530f26cab9341-6cpwqdw',
#  b'/logged_users/JakubPerzylo/0': b'Adam',
#  b'/logged_users/JakubPerzylo/1': b'Borys',
#  b'/logged_users/JakubPerzylo/10': b'Kamil',
#  b'/logged_users/JakubPerzylo/11': b'Leon',
#  b'/logged_users/JakubPerzylo/12': b'Marek',
#  b'/logged_users/JakubPerzylo/13': b'Norbert',
#  b'/logged_users/JakubPerzylo/14': b'Oskar',
#  b'/logged_users/JakubPerzylo/15': b'Patryk',
#  b'/logged_users/JakubPerzylo/16': b'Rafa\xc5\x82',
#  b'/logged_users/JakubPerzylo/17': b'Stefan',
#  b'/logged_users/JakubPerzylo/18': b'Tadeusz',
#  b'/logged_users/JakubPerzylo/2': b'Cezary',
#  b'/logged_users/JakubPerzylo/3': b'Damian',
#  b'/logged_users/JakubPerzylo/4': b'Emil',
#  b'/logged_users/JakubPerzylo/5': b'Filip',
#  b'/logged_users/JakubPerzylo/6': b'Gustaw',
#  b'/logged_users/JakubPerzylo/7': b'Henryk',
#  b'/logged_users/JakubPerzylo/8': b'Ignacy',
#  b'/logged_users/JakubPerzylo/9': b'Jacek',
#  b'/logged_users/Kamil': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/KamilKoczera': b'KamilKoczera-hostname',
#  b'/logged_users/KamilKoczera/Adam': b'Adam',
#  b'/logged_users/KamilKoczera/Borys': b'Borys',
#  b'/logged_users/KamilKoczera/Cezary': b'Cezary',
#  b'/logged_users/KamilKoczera/Damian': b'Damian',
#  b'/logged_users/KamilKoczera/Emil': b'Emil',
#  b'/logged_users/KamilKoczera/Filip': b'Filip',
#  b'/logged_users/KamilKoczera/Gustaw': b'Gustaw',
#  b'/logged_users/KamilKoczera/Henryk': b'Henryk',
#  b'/logged_users/KamilKoczera/Ignacy': b'Ignacy',
#  b'/logged_users/KamilKoczera/Jacek': b'Jacek',
#  b'/logged_users/KamilKoczera/Kamil': b'Kamil',
#  b'/logged_users/KamilKoczera/Leon': b'Leon',
#  b'/logged_users/KamilKoczera/Marek': b'Marek',
#  b'/logged_users/KamilKoczera/Norbert': b'Norbert',
#  b'/logged_users/KamilKoczera/Oskar': b'Oskar',
#  b'/logged_users/KamilKoczera/Patryk': b'Patryk',
#  b'/logged_users/KamilKoczera/Rafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/KamilKoczera/Stefan': b'Stefan',
#  b'/logged_users/KamilKoczera/Tadeusz': b'Tadeusz',
#  b'/logged_users/KamilKoczera/data': b'KamilKoczera-hostname',
#  b'/logged_users/KamilKoczera/key_m_0': b'Adam_transaction',
#  b'/logged_users/KamilKoczera/key_m_1': b'Borys_transaction',
#  b'/logged_users/KamilKoczera/key_m_10': b'Kamil_transaction',
#  b'/logged_users/KamilKoczera/key_m_11': b'Leon_transaction',
#  b'/logged_users/KamilKoczera/key_m_12': b'Marek_transaction',
#  b'/logged_users/KamilKoczera/key_m_13': b'Norbert_transaction',
#  b'/logged_users/KamilKoczera/key_m_14': b'Oskar_transaction',
#  b'/logged_users/KamilKoczera/key_m_15': b'Patryk_transaction',
#  b'/logged_users/KamilKoczera/key_m_16': b'Rafa\xc5\x82_transaction',
#  b'/logged_users/KamilKoczera/key_m_17': b'Stefan_transaction',
#  b'/logged_users/KamilKoczera/key_m_18': b'Tadeusz_transaction',
#  b'/logged_users/KamilKoczera/key_m_2': b'Cezary_transaction',
#  b'/logged_users/KamilKoczera/key_m_3': b'Damian_transaction',
#  b'/logged_users/KamilKoczera/key_m_4': b'Emil_transaction',
#  b'/logged_users/KamilKoczera/key_m_5': b'Filip_transaction',
#  b'/logged_users/KamilKoczera/key_m_6': b'Gustaw_transaction',
#  b'/logged_users/KamilKoczera/key_m_7': b'Henryk_transaction',
#  b'/logged_users/KamilKoczera/key_m_8': b'Ignacy_transaction',
#  b'/logged_users/KamilKoczera/key_m_9': b'Jacek_transaction',
#  b'/logged_users/KamilKoczera/names/': b'test',
#  b'/logged_users/KamilKoczera/names/Adam': b'Adam',
#  b'/logged_users/KamilKoczera/names/Borys': b'Borys',
#  b'/logged_users/KamilKoczera/names/Cezary': b'Cezary',
#  b'/logged_users/KamilKoczera/names/Damian': b'Damian',
#  b'/logged_users/KamilKoczera/names/Emil': b'Emil_atomic',
#  b'/logged_users/KamilKoczera/names/Filip': b'Filip',
#  b'/logged_users/KamilKoczera/names/Gustaw': b'Gustaw',
#  b'/logged_users/KamilKoczera/names/Henryk': b'Henryk',
#  b'/logged_users/KamilKoczera/names/Ignacy': b'Ignacy',
#  b'/logged_users/KamilKoczera/names/Jacek': b'Jacek',
#  b'/logged_users/KamilKoczera/names/Kamil': b'Kamil',
#  b'/logged_users/KamilKoczera/names/Leon': b'Leon',
#  b'/logged_users/KamilKoczera/names/Marek': b'Marek',
#  b'/logged_users/KamilKoczera/names/Norbert': b'Norbert',
#  b'/logged_users/KamilKoczera/names/Oskar': b'Oskar',
#  b'/logged_users/KamilKoczera/names/Patryk': b'Patryk',
#  b'/logged_users/KamilKoczera/names/Rafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/KamilKoczera/names/Stefan': b'Stefan',
#  b'/logged_users/KamilKoczera/names/Tadeusz': b'Tadeusz',
#  b'/logged_users/KamilKoczeraAdam': b'Adam',
#  b'/logged_users/KamilKoczeraBorys': b'Borys',
#  b'/logged_users/KamilKoczeraCezary': b'Cezary',
#  b'/logged_users/KamilKoczeraDamian': b'Damian',
#  b'/logged_users/KamilKoczeraEmil': b'Emil',
#  b'/logged_users/KamilKoczeraFilip': b'Filip',
#  b'/logged_users/KamilKoczeraGustaw': b'Gustaw',
#  b'/logged_users/KamilKoczeraHenryk': b'Henryk',
#  b'/logged_users/KamilKoczeraIgnacy': b'Ignacy',
#  b'/logged_users/KamilKoczeraJacek': b'Jacek',
#  b'/logged_users/KamilKoczeraKamil': b'Kamil',
#  b'/logged_users/KamilKoczeraLeon': b'Leon',
#  b'/logged_users/KamilKoczeraMarek': b'Marek',
#  b'/logged_users/KamilKoczeraNorbert': b'Norbert',
#  b'/logged_users/KamilKoczeraOskar': b'Oskar',
#  b'/logged_users/KamilKoczeraPatryk': b'Patryk',
#  b'/logged_users/KamilKoczeraRafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/KamilKoczeraStefan': b'Stefan',
#  b'/logged_users/KamilKoczeraTadeusz': b'Tadeusz',
#  b'/logged_users/KamilKoczeranames': b'Tadeusz',
#  b'/logged_users/Kocimski/Adam': b'Adam',
#  b'/logged_users/Kocimski/Borys': b'Borys',
#  b'/logged_users/Kocimski/Cezary': b'Cezary',
#  b'/logged_users/Kocimski/Damian': b'Damian',
#  b'/logged_users/Kocimski/Emil': b'Emil',
#  b'/logged_users/Kocimski/Filip': b'Filip',
#  b'/logged_users/Kocimski/Gustaw': b'Gustaw',
#  b'/logged_users/Kocimski/Henryk': b'Henryk',
#  b'/logged_users/Kocimski/Ignacy': b'Ignacy',
#  b'/logged_users/Kocimski/Jacek': b'Kazimierz',
#  b'/logged_users/Kocimski/Kamil': b'Kamil',
#  b'/logged_users/Kocimski/Leon': b'Leon',
#  b'/logged_users/Kocimski/Marek': b'Marek',
#  b'/logged_users/Kocimski/Norbert': b'Norbert',
#  b'/logged_users/Kocimski/Oskar': b'Oskar',
#  b'/logged_users/Kocimski/Patryk': b'Patryk',
#  b'/logged_users/Kocimski/Rafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/Kocimski/Stefan': b'Stefan',
#  b'/logged_users/Kocimski/Tadeusz': b'Tadeusz',
#  b'/logged_users/Lechowicz': b'notebook-condafree1py3681d3d2d480474a18b8276572c8600ae7-68hmpxx',
#  b'/logged_users/Leon': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Marek': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Maria/Adam': b'Adam',
#  b'/logged_users/Maria/Borys': b'Borys',
#  b'/logged_users/Maria/Cezary': b'Cezary',
#  b'/logged_users/Maria/Damian': b'Damian',
#  b'/logged_users/Maria/Emil': b'Emil',
#  b'/logged_users/Maria/Filip': b'Filip',
#  b'/logged_users/Maria/Gustaw': b'Gustaw',
#  b'/logged_users/Maria/Henryk': b'Henryk',
#  b'/logged_users/Maria/Ignacy': b'Ignacy',
#  b'/logged_users/Maria/Jacek': b'Jacek',
#  b'/logged_users/Maria/Kamil': b'Kamil',
#  b'/logged_users/Maria/Leon': b'Leon',
#  b'/logged_users/Maria/Marek': b'Marek',
#  b'/logged_users/Maria/Norbert': b'Norbert',
#  b'/logged_users/Maria/Oskar': b'Oskar',
#  b'/logged_users/Maria/Patryk': b'Patryk',
#  b'/logged_users/Maria/Rafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/Maria/Stefan': b'Stefan',
#  b'/logged_users/Maria/Tadeusz': b'Tadeusz',
#  b'/logged_users/MichalW/users': b'Tadeusz',
#  b'/logged_users/MichalW/users/Adam': b'Adam',
#  b'/logged_users/MichalW/users/Borys': b'Borys',
#  b'/logged_users/MichalW/users/Cezary': b'Cezary',
#  b'/logged_users/MichalW/users/Damian': b'Damian',
#  b'/logged_users/MichalW/users/Emil': b'Emil',
#  b'/logged_users/MichalW/users/Filip': b'Filip',
#  b'/logged_users/MichalW/users/Gustaw': b'Gustaw',
#  b'/logged_users/MichalW/users/Henryk': b'Henryk',
#  b'/logged_users/MichalW/users/Ignacy': b'Ignacy',
#  b'/logged_users/MichalW/users/Jacek': b'Jacek',
#  b'/logged_users/MichalW/users/Kamil': b'Kamil',
#  b'/logged_users/MichalW/users/Leon': b'Leon',
#  b'/logged_users/MichalW/users/Marek': b'Marek',
#  b'/logged_users/MichalW/users/Norbert': b'Norbert',
#  b'/logged_users/MichalW/users/Oskar': b'Oskar',
#  b'/logged_users/MichalW/users/Patryk': b'Patryk',
#  b'/logged_users/MichalW/users/Rafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/MichalW/users/Stefan': b'Stefan',
#  b'/logged_users/MichalW/users/Tadeusz': b'Tadeusz',
#  b'/logged_users/Niechaj': b'Tadeusz',
#  b'/logged_users/Niechaj/key_n_0': b'Adam',
#  b'/logged_users/Niechaj/key_n_1': b'Borys',
#  b'/logged_users/Niechaj/key_n_10': b'Kamil',
#  b'/logged_users/Niechaj/key_n_11': b'Leon',
#  b'/logged_users/Niechaj/key_n_12': b'Marek',
#  b'/logged_users/Niechaj/key_n_13': b'Norbert',
#  b'/logged_users/Niechaj/key_n_14': b'Oskar',
#  b'/logged_users/Niechaj/key_n_15': b'Patryk',
#  b'/logged_users/Niechaj/key_n_16': b'Rafa\xc5\x82',
#  b'/logged_users/Niechaj/key_n_17': b'Stefan',
#  b'/logged_users/Niechaj/key_n_18': b'Tadeusz',
#  b'/logged_users/Niechaj/key_n_2': b'Cezary',
#  b'/logged_users/Niechaj/key_n_3': b'Damian',
#  b'/logged_users/Niechaj/key_n_4': b'Emil',
#  b'/logged_users/Niechaj/key_n_5': b'Filip',
#  b'/logged_users/Niechaj/key_n_6': b'Gustaw',
#  b'/logged_users/Niechaj/key_n_7': b'Henryk',
#  b'/logged_users/Niechaj/key_n_8': b'Ignacy',
#  b'/logged_users/Niechaj/key_n_9': b'Jacek',
#  b'/logged_users/Norbert': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/NotWatchedKey': b'value first',
#  b'/logged_users/Oskar': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Patryk': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/Patryk/key': b'value',
#  b'/logged_users/Piotr Swiderski': b'notebook-b1d4673d48614999b889c4f27a801961-755d7bbffb-rb7gt',
#  b'/logged_users/Przewloka/Adam': b'Adam',
#  b'/logged_users/Przewloka/Borys': b'Borys',
#  b'/logged_users/Przewloka/Cezary': b'Cezary',
#  b'/logged_users/Przewloka/Damian': b'Damian',
#  b'/logged_users/Przewloka/Emil': b'Emil',
#  b'/logged_users/Przewloka/Filip': b'Filip',
#  b'/logged_users/Przewloka/Gustaw': b'Gustaw',
#  b'/logged_users/Przewloka/Henryk': b'Henryk',
#  b'/logged_users/Przewloka/Ignacy': b'Ignacy',
#  b'/logged_users/Przewloka/Jacek': b'Jacek',
#  b'/logged_users/Przewloka/Kamil': b'Kamil',
#  b'/logged_users/Przewloka/Leon': b'Leon',
#  b'/logged_users/Przewloka/Marek': b'Marek',
#  b'/logged_users/Przewloka/Norbert': b'Norbert',
#  b'/logged_users/Przewloka/Oskar': b'Oskar',
#  b'/logged_users/Przewloka/Patryk': b'Patryk',
#  b'/logged_users/Przewloka/Rafa\xc5\x82': b'Rafa\xc5\x82',
#  b'/logged_users/Przewloka/Stefan': b'Stefan',
#  b'/logged_users/Przewloka/Tadeusz': b'Tadeusz',
#  b'/logged_users/Rafa\xc5\x82': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/SSwierk': b'notebook-condafree1py36ca7d2d12048646249d87c4564e316d78-78lfp26',
#  b'/logged_users/SZYMON': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/Stefan': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/SuperEmil': b'normalEmil',
#  b'/logged_users/Tadeusz': b'notebook-premium2py36f501191650b745849cf3df420b3c3644-79c52zpk9',
#  b'/logged_users/UTumilovich': b'notebook-cb0ffef2f3e240b4b8a72f0a17ed8bba-d57ff64d8-sj7qq',
#  b'/logged_users/Uladzislau': b'notebook-cb0ffef2f3e240b4b8a72f0a17ed8bba-d57ff64d8-sj7qq',
#  b'/logged_users/User1': b'val3',
#  b'/logged_users/WatchedKey': b'value second',
#  b'/logged_users/Wolski': b'Wolski-Notebook',
#  b'/logged_users/Xert/Adam': b'Adam-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Borys': b'Borys-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Cezary': b'Cezary-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Damian': b'Damian-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Emil': b'Emil-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Filip': b'Filip-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Gustaw': b'Gustaw-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Henryk': b'Henryk-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Ignacy': b'Ignacy-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Jacek': b'Jacek-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Kamil': b'Kamil-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Leon': b'Leon-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Marek': b'Marek-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Norbert': b'Norbert-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Oskar': b'Oskar-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Patryk': b'Patryk-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Rafa\xc5\x82': b'Rafa\xc5\x82-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Stefan': b'Stefan-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/Tadeusz': b'Tadeusz-notebook-condafree1py365026a77c8dbf4b5392587b5447eabe87-6bcglbn',
#  b'/logged_users/Xert/failure': b'true',
#  b'/logged_users/acwikla/Adam': b'Adam-acwikla-hostname',
#  b'/logged_users/acwikla/Borys': b'Borys-acwikla-hostname',
#  b'/logged_users/acwikla/Cezary': b'Cezary-acwikla-hostname',
#  b'/logged_users/acwikla/Damian': b'Damian-acwikla-hostname',
#  b'/logged_users/acwikla/Emil': b'Emil-acwikla-hostname',
#  b'/logged_users/acwikla/Filip': b'Filip-acwikla-hostname_new',
#  b'/logged_users/acwikla/Gustaw': b'Gustaw-acwikla-hostname',
#  b'/logged_users/acwikla/Henryk': b'Henryk-acwikla-hostname',
#  b'/logged_users/acwikla/Ignacy': b'Ignacy-acwikla-hostname',
#  b'/logged_users/acwikla/Jacek': b'Jacek-acwikla-hostname',
#  b'/logged_users/acwikla/Kamil': b'Kamil-acwikla-hostname',
#  b'/logged_users/acwikla/Leon': b'Leon-acwikla-hostname',
#  b'/logged_users/acwikla/Marek': b'Marek-acwikla-hostname',
#  b'/logged_users/acwikla/Norbert': b'Norbert-acwikla-hostname',
#  b'/logged_users/acwikla/Oskar': b'Oskar-acwikla-hostname',
#  b'/logged_users/acwikla/Patryk': b'Patryk-acwikla-hostname',
#  b'/logged_users/acwikla/Rafa\xc5\x82': b'Rafa\xc5\x82-acwikla-hostname',
#  b'/logged_users/acwikla/Stefan': b'Stefan-acwikla-hostname',
#  b'/logged_users/acwikla/Tadeusz': b'Tadeusz-acwikla-hostname',
#  b'/logged_users/agierlach': b'Tadeusz-super-host',
#  b'/logged_users/agierlach/Adam': b'Adam-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Borys': b'Borys-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Cezary': b'Cezary-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Damian': b'Damian-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Emil': b'Emil-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Filip': b'Filip-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Gustaw': b'Gustaw-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Ignacy': b'Ignacy-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Jacek': b'Jacek-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Kamil': b'Kamil-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Leon': b'asdf',
#  b'/logged_users/agierlach/Marek': b'Marek-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Norbert': b'Norbert-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Oskar': b'Oskar-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Patryk': b'Patryk-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Rafa\xc5\x82': b'Rafa\xc5\x82-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Stefan': b'Stefan-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/Tadeusz': b'Tadeusz-notebook-condafree1py369fe46cb22f384d5d9bb015906bdbdbbf-6fcgqcp',
#  b'/logged_users/agierlach/to_watch': b'1333',
#  b'/logged_users/anything': b'value',
#  b'/logged_users/being_watched': b'value',
#  b'/logged_users/beneckimateusz': b'139',
#  b'/logged_users/dsxuser': b'notebook-condafree1py36ca7d2d12048646249d87c4564e316d78-6f4tbxz',
#  b'/logged_users/errors': b'condition failed',
#  b'/logged_users/errors_n_0': b'condition failed',
#  b'/logged_users/errors_n_1': b'condition failed',
#  b'/logged_users/errors_n_10': b'condition failed',
#  b'/logged_users/errors_n_11': b'condition failed',
#  b'/logged_users/errors_n_12': b'condition failed',
#  b'/logged_users/errors_n_13': b'condition failed',
#  b'/logged_users/errors_n_14': b'condition failed',
#  b'/logged_users/errors_n_15': b'condition failed',
#  b'/logged_users/errors_n_16': b'condition failed',
#  b'/logged_users/errors_n_17': b'condition failed',
#  b'/logged_users/errors_n_18': b'condition failed',
#  b'/logged_users/errors_n_2': b'condition failed',
#  b'/logged_users/errors_n_3': b'condition failed',
#  b'/logged_users/errors_n_4': b'condition failed',
#  b'/logged_users/errors_n_5': b'condition failed',
#  b'/logged_users/errors_n_6': b'condition failed',
#  b'/logged_users/errors_n_7': b'condition failed',
#  b'/logged_users/errors_n_8': b'condition failed',
#  b'/logged_users/errors_n_9': b'condition failed',
#  b'/logged_users/grzegorz/Adam': b'Adam-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Borys': b'Borys-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Cezary': b'Cezary-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Damian': b'Damian-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Emil': b'Emil-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Filip': b'Filip-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Gustaw': b'Gustaw-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Henryk': b'Henryk-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Ignacy': b'Ignacy-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Jacek': b'Jacek-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Kamil': b'Kamil-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Leon': b'Leon-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Marek': b'Marek-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Norbert': b'Norbert-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Oskar': b'Oskar-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Patryk': b'Patryk-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Rafa\xc5\x82': b'Rafa\xc5\x82-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Stefan': b'Stefan-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/grzegorz/Tadeusz': b'Tadeusz-notebook-condafree1py36a83819e79c3e4b399e4058c062729361-566n72k',
#  b'/logged_users/kaminski': b'notebook-condafree1py36316d9510130e4ef2aa895ec34c3f8c96-5dpp5sp',
#  b'/logged_users/kania//Adam': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Borys': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Cezary': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Damian': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Emil': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Filip': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Gustaw': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Henryk': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Ignacy': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Jacek': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Kamil': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Leon': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Marek': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Norbert': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Oskar': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Patryk': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Rafa\xc5\x82': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Stefan': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania//Tadeusz': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Adam': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Borys': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Cezary': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Damian': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Emil': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Filip': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Gustaw': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Henryk': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Ignacy': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Jacek': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Kamil': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Leon': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Marek': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Norbert': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Oskar': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Patryk': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Rafa\xc5\x82': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/SZYMON': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Stefan': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kania/Tadeusz': b'notebook-condafree1py369aa1e8cdc0ff47c7be259009f850542a-75xqfbc',
#  b'/logged_users/kawalec': b'DESKTOP-UIJMA2K',
#  b'/logged_users/kawalec/Adam': b'Adam-transaction',
#  b'/logged_users/kawalec/Borys': b'Borys-transaction',
#  b'/logged_users/kawalec/Cezary': b'Cezary-transaction',
#  b'/logged_users/kawalec/Damian': b'Damian-transaction',
#  b'/logged_users/kawalec/Emil': b'Emil-transaction',
#  b'/logged_users/kawalec/Filip': b'Filip-transaction',
#  b'/logged_users/kawalec/Gustaw': b'Gustaw Atomic Replace',
#  b'/logged_users/kawalec/Henryk': b'Henryk-transaction',
#  b'/logged_users/kawalec/Ignacy': b'Ignacy-transaction',
#  b'/logged_users/kawalec/Jacek': b'Jacek-transaction',
#  b'/logged_users/kawalec/Kamil': b'Kamil-transaction',
#  b'/logged_users/kawalec/Leon': b'Leon-transaction',
#  b'/logged_users/kawalec/Marek': b'Marek-transaction',
#  b'/logged_users/kawalec/Norbert': b'Norbert-transaction',
#  b'/logged_users/kawalec/Oskar': b'Oskar-transaction',
#  b'/logged_users/kawalec/Patryk': b'Patryk-transaction',
#  b'/logged_users/kawalec/Rafa\xc5\x82': b'Rafa\xc5\x82-transaction',
#  b'/logged_users/kawalec/Stefan': b'Stefan-transaction',
#  b'/logged_users/kawalec/Tadeusz': b'Tadeusz-transaction',
#  b'/logged_users/key': b'Tadeusz',
#  b'/logged_users/key_0': b'Adam',
#  b'/logged_users/key_1': b'Borys',
#  b'/logged_users/key_10': b'Kamil',
#  b'/logged_users/key_11': b'Leon',
#  b'/logged_users/key_12': b'Marek',
#  b'/logged_users/key_13': b'Norbert',
#  b'/logged_users/key_14': b'Oskar',
#  b'/logged_users/key_15': b'Patryk',
#  b'/logged_users/key_16': b'Rafa\xc5\x82',
#  b'/logged_users/key_17': b'Stefan',
#  b'/logged_users/key_18': b'Tadeusz',
#  b'/logged_users/key_2': b'Cezary',
#  b'/logged_users/key_3': b'Damian',
#  b'/logged_users/key_4': b'Emil',
#  b'/logged_users/key_5': b'Filip',
#  b'/logged_users/key_6': b'Gustaw',
#  b'/logged_users/key_7': b'Henryk',
#  b'/logged_users/key_8': b'Ignacy',
#  b'/logged_users/key_9': b'Jacek',
#  b'/logged_users/key_n_0': b'Adam',
#  b'/logged_users/key_n_1': b'Borys',
#  b'/logged_users/key_n_10': b'Kamil',
#  b'/logged_users/key_n_11': b'Leon',
#  b'/logged_users/key_n_12': b'Marek',
#  b'/logged_users/key_n_13': b'Norbert',
#  b'/logged_users/key_n_14': b'Oskar',
#  b'/logged_users/key_n_15': b'Patryk',
#  b'/logged_users/key_n_16': b'Rafa\xc5\x82',
#  b'/logged_users/key_n_17': b'Stefan',
#  b'/logged_users/key_n_18': b'Tadeusz',
#  b'/logged_users/key_n_19': b'Albert',
#  b'/logged_users/key_n_2': b'Cezary',
#  b'/logged_users/key_n_3': b'Damian',
#  b'/logged_users/key_n_4': b'Emil',
#  b'/logged_users/key_n_5': b'Filip',
#  b'/logged_users/key_n_6': b'Gustaw',
#  b'/logged_users/key_n_7': b'Henryk',
#  b'/logged_users/key_n_8': b'Ignacy',
#  b'/logged_users/key_n_9': b'Jacek',
#  b'/logged_users/konrad': b'konrad-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Adam': b'Adam-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Borys': b'Borys-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Cezary': b'Cezary-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Damian': b'Damian-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Emil': b'new_value',
#  b'/logged_users/konrad/Filip': b'Filip-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Gustaw': b'Gustaw-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Henryk': b'Henryk-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Ignacy': b'Ignacy-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Jacek': b'Jacek-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Kamil': b'Kamil-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Leon': b'Leon-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Marek': b'Marek-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Norbert': b'Norbert-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Oskar': b'Oskar-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Patryk': b'Patryk-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Rafa\xc5\x82': b'Rafa\xc5\x82-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Stefan': b'Stefan-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/Tadeusz': b'Tadeusz-notebook-condafree1py369ae2dd2798eb42529d327e7e89b639a8-672lvkb',
#  b'/logged_users/konrad/hello_watch': b'watch',
#  b'/logged_users/kustra': b'notebook-0b34268899e14795b60b6d36d0883ae1-576b4b5d8d-w62xc',
#  b'/logged_users/lock': b'value',
#  b'/logged_users/log': b'value was there',
#  b'/logged_users/maciejKozub': b'notebook-condafree1py36df71c07b4e3b4ebe8de418e54ed7b1b8-cbcxtkz',
#  b'/logged_users/maciejKozub/Adam': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Borys': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Cezary': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Damian': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Emil': b'22',
#  b'/logged_users/maciejKozub/Filip': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Gustaw': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Henryk': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Ignacy': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Jacek': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Kamil': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Leon': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Marek': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Norbert': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Oskar': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Patryk': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Rafa\xc5\x82': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Stefan': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/Tadeusz': b'notebook-conda2py36df71c07b4e3b4ebe8de418e54ed7b1b8-8487f9626v8',
#  b'/logged_users/maciejKozub/test': b'lock_test',
#  b'/logged_users/magdalena': b'notebook-condafree1py365bb341db1c18409987fd62af4cdf6777-68sw9z2',
#  b'/logged_users/milosz': b'notebook-438cad81f4974877a0c254a6d6ff0145-58f95b7948-zfpxd',
#  b'/logged_users/mysliwiec/Adam': b'Adam-hostname2',
#  b'/logged_users/mysliwiec/Borys': b'Borys-hostname2',
#  b'/logged_users/mysliwiec/Cezary': b'Cezary-hostname2',
#  b'/logged_users/mysliwiec/Damian': b'Damian-hostname2',
#  b'/logged_users/mysliwiec/Emil': b'Emil-hostname2',
#  b'/logged_users/mysliwiec/Filip': b'Filip-hostname2',
#  b'/logged_users/mysliwiec/Gustaw': b'Gustaw-hostname2',
#  b'/logged_users/mysliwiec/Henryk': b'Henryk-hostname2',
#  b'/logged_users/mysliwiec/Ignacy': b'Ignacy-hostname2',
#  b'/logged_users/mysliwiec/Jacek': b'Jacek-hostname2',
#  b'/logged_users/mysliwiec/Jakub Mysliwiec': b'notebook-condafree1py3690879dede28a40ed88e530f26cab9341-6cpwqdw',
#  b'/logged_users/mysliwiec/Kamil': b'Kamil-hostname2',
#  b'/logged_users/mysliwiec/Leon': b'Leon-hostname2',
#  b'/logged_users/mysliwiec/Marek': b'Marek-hostname2',
#  b'/logged_users/mysliwiec/Norbert': b'Norbert-hostname2',
#  b'/logged_users/mysliwiec/Oskar': b'Oskar-hostname2',
#  b'/logged_users/mysliwiec/Patryk': b'Patryk-hostname2',
#  b'/logged_users/mysliwiec/Rafa\xc5\x82': b'Rafa\xc5\x82-hostname2',
#  b'/logged_users/mysliwiec/Stefan': b'Stefan-hostname2',
#  b'/logged_users/mysliwiec/Tadeusz': b'Tadeusz-hostname2',
#  b'/logged_users/mysliwiec/callback': b'{callback}-hostname',
#  b'/logged_users/mysliwiec/refresh_user': b'{callback}-hostname',
#  b'/logged_users/nalepa': b'notebook-db4dad02cab04ea3be358367155cc493-5cb65bd564-dgqgr',
#  b'/logged_users/skusnierz/0': b'Adam',
#  b'/logged_users/skusnierz/1': b'Borys',
#  b'/logged_users/skusnierz/10': b'Kamil',
#  b'/logged_users/skusnierz/11': b'Leon',
#  b'/logged_users/skusnierz/12': b'Marek',
#  b'/logged_users/skusnierz/13': b'Norbert',
#  b'/logged_users/skusnierz/14': b'Oskar',
#  b'/logged_users/skusnierz/15': b'Patryk',
#  b'/logged_users/skusnierz/16': b'Rafa\xc5\x82',
#  b'/logged_users/skusnierz/17': b'Stefan',
#  b'/logged_users/skusnierz/18': b'Tadeusz',
#  b'/logged_users/skusnierz/2': b'Cezary',
#  b'/logged_users/skusnierz/3': b'Damian',
#  b'/logged_users/skusnierz/4': b'Emil',
#  b'/logged_users/skusnierz/5': b'Filip',
#  b'/logged_users/skusnierz/6': b'Gustaw',
#  b'/logged_users/skusnierz/7': b'Henryk',
#  b'/logged_users/skusnierz/8': b'Ignacy',
#  b'/logged_users/skusnierz/9': b'Jacek',
#  b'/logged_users/solecki': b'Tadeusz-notebook-condafree1py362847d525672542009895af0d8d60e2f2-79xg5sk',
#  b'/logged_users/solecki/Adam': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Borys': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Cezary': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Damian': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Emil': b'Emil',
#  b'/logged_users/solecki/Filip': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Gustaw': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Henryk': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Ignacy': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Jacek': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Kamil': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Leon': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Marek': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Norbert': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Oskar': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Patryk': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Rafa\xc5\x82': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Stefan': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/solecki/Tadeusz': b'notebook-condafree1py362847d525672542009895af0d8d60e2f2-86rblb8',
#  b'/logged_users/status': b'Success',
#  b'/logged_users/szelemeh/Adam': b'Adam-host',
#  b'/logged_users/szelemeh/Borys': b'Borys-host',
#  b'/logged_users/szelemeh/Cezary': b'Cezary-host',
#  b'/logged_users/szelemeh/Damian': b'Damian-host',
#  b'/logged_users/szelemeh/Emil': b'Emil-host',
#  b'/logged_users/szelemeh/Filip': b'Filip-host',
#  b'/logged_users/szelemeh/Gustaw': b'Gustaw-host',
#  b'/logged_users/szelemeh/Henryk': b'Henryk-host',
#  b'/logged_users/szelemeh/Ignacy': b'Ignacy-host',
#  b'/logged_users/szelemeh/Jacek': b'Jacek-host',
#  b'/logged_users/szelemeh/Kamil': b'Kamil-host',
#  b'/logged_users/szelemeh/Leon': b'Leon-host',
#  b'/logged_users/szelemeh/Marek': b'Marek-host',
#  b'/logged_users/szelemeh/Norbert': b'Norbert-host',
#  b'/logged_users/szelemeh/Oskar': b'Oskar-host',
#  b'/logged_users/szelemeh/Patryk': b'Patryk-host',
#  b'/logged_users/szelemeh/Rafa\xc5\x82': b'Rafa\xc5\x82-host',
#  b'/logged_users/szelemeh/Stefan': b'Stefan-host',
#  b'/logged_users/szelemeh/Tadeusz': b'Tadeusz-host',
#  b'/logged_users/szelemeh/szelemeh': b'Tadeusz-host',
#  b'/logged_users/tempUser3': b'TempUser3-hostname',
#  b'/logged_users/tempUser5': b'TempUser5-hostname3',
#  b'/logged_users/tmp_user': b'tmp_user-hostname',
#  b'/logged_users/watchTest': b'someValue 2'}

# %% [markdown]
# ### Task 4 : Same as Task2, but use transaction
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# for all names in table fixedUsers register the appropriate key value pairs, use transaction to make it a single request
# (Have you noticed any difference in execution time?)

# %%
etcd.transaction(
        compare=[etcd.transactions.version(cfgRoot) == 0],
        success=[etcd.transactions.put('{}/{}'.format(cfgRoot, user), 'user-{}'.format(user)) for user in fixed_users],
        failure=[etcd.transactions.put('/tmp/errors', 'condition failed')]
    )
# Out:
# (False, [response_put {
#     header {
#       revision: 354975
#     }
#   }])

# %% [markdown]
# ### Task 5 : Get single key (e.g. status of transaction)
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# Check the key you are modifying in on-failure handler in previous task

# %%
for info in etcd.get_prefix('/tmp/errors'):
    print(info)
# Out:
# (b'condition failed', <etcd3.client.KVMetadata object at 0x7f65dc4d4710>)

# %% [markdown]
# ### Task 6 : Get range of Keys (Emil -> Oskar)
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# - Get range of keys
# - Is it inclusive / exclusive?
# - Sort the resposne descending
# - Sort the resposne descending by value not by key

# %%
range_from = cfgRoot + '/' + 'Emil'
range_to = cfgRoot + '/' + 'Oskar'
for key in etcd.get_range(range_from, range_to, sort_order='descend', sort_target='value'):
    print(key)
# Out:
# (b'value first', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'testmessage3', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'test_9', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'test', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-condafree1py3690879dede28a40ed88e530f26cab9341-6cpwqdw', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-condafree1py3681d3d2d480474a18b8276572c8600ae7-68hmpxx', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-a7823551d9b84fd3b085958036c5f597-d469f8875-ltf7p', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'notebook-66c43e4471114fa295d284b8afdefbb0-58bc66c8d6-9bxrd', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'kochana', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'condition failed', <etcd3.client.KVMetadata object at 0x7f65dc4d4e48>)
# (b'condition failed', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Tadeusz_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e48>)
# (b'Tadeusz-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Tadeusz-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Tadeusz-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e48>)
# (b'Tadeusz-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Tadeusz', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Stefan-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Stefan-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Stefan', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Rafa\xc5\x82-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Rafa\xc5\x82-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Rafa\xc5\x82', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Patryk_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Patryk-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Patryk-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Patryk-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Patryk-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Patryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Oskar-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Oskar-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Oskar', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Norbert_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Norbert-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Norbert-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Norbert-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Norbert-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e48>)
# (b'Norbert - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Norbert', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Marek_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Marek-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Marek-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Marek-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Marek-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Marek - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Marek', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Leon_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Leon-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Leon-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Leon-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Leon-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Leon - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Leon', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Kazimierz', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Kamil_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'KamilKoczera-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4f60>)
# (b'KamilKoczera-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Kamil-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Kamil-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Kamil-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Kamil-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Kamil - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Kamil', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Jacek_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Jacek-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Jacek-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Jacek-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Jacek-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Jacek - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Jacek', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Ignacy_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Ignacy-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Ignacy-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Ignacy-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Ignacy-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Ignacy - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Ignacy', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Henryk_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Henryk-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Henryk-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Henryk-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Henryk-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Henryk - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Henryk', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Gustaw_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Gustaw-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Gustaw-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Gustaw-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Gustaw-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Gustaw - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Gustaw', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Filip_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Filip-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Filip-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Filip-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Filip-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Filip - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Filip', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Emil_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Emil_atomic', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Emil-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Emil-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Emil-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Emil-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Emil - hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Emil', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Damian-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Damian-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Damian', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Cezary-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Cezary-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Cezary', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Borys_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Borys-notebook-condafree1py3621c9aec184684c4586519a69becb7bf2-785r4k8', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Borys-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Borys-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Borys-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Borys', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Adam_transaction', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Adam-notebook-3dd95954209d46018d78a714da459b6a-545894974-srlx9', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Adam-hostname', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Adam-hostname', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dd5e2470>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dc4d4da0>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dc4d4e10>)
# (b'Adam', <etcd3.client.KVMetadata object at 0x7f65dc4d4780>)

# %% [markdown]
# ### Task 7: Atomic Replace
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# Do it a few times, check if value has been replaced depending on condition

# %%
for user in fixed_users:
    result = etcd.replace('{}/{}'.format(cfgRoot, user), user, 'new' + user)
    print(user, ':', result)
# Out:
# Adam : False
# Borys : False
# Cezary : False
# Damian : False
# Emil : False
# Filip : False
# Gustaw : False
# Henryk : False
# Ignacy : False
# Jacek : False
# Kamil : False
# Leon : False
# Marek : False
# Norbert : False
# Oskar : False
# Patryk : False
# Rafał : False
# Stefan : False
# Tadeusz : False

# %% [markdown]
# ### Task 8 : Create lease - use it to create expiring key
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# You can create a key that will be for limited time
# add user that will expire after a few seconds
#
# Tip: Use lease

# %%
import time

key = cfgRoot + '/' + 'blaise10sec'
value = '10sec'
print(key)
lease = etcd.lease(ttl=2)

for user in etcd.get_prefix(key):
    print(user)
    
time.sleep(4)

print('after 4 seconds:')
for user in etcd.get_prefix(key):
    print(user)
# Out:
# /logged_users/blaise10sec
# after 4 seconds:

# %% [markdown]
# ### Task 9 : Create key that will expire after you close the connection to etcd
#
# Tip: use threading library to refresh your lease

# %%
import threading

lease = etcd.lease(ttl=5)

key = cfgRoot + '/' + 'blaise10sec'
value = '10sec'
etcd.put(key, value, lease=lease)

def refreshLease():
    lease.refresh()
    threading.Timer(1, refreshLease).start()

refreshLease()

print(etcd.get(key))
time.sleep(10)
print(etcd.get(key))
# Out:
# (b'10sec', <etcd3.client.KVMetadata object at 0x7f65dc4da6d8>)
# (b'10sec', <etcd3.client.KVMetadata object at 0x7f65dc4c4278>)

# %% [markdown]
# ### Task 10: Use lock to protect section of code
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html

# %%
with etcd.lock('my_lock', ttl=5) as lock:
    print('Is acquaired?', lock.is_acquired())
    # some code
    lock.acquire()
    lock.release()
    print('Is acquaired?', lock.is_acquired())
# Out:
# Is acquaired? True
# Is acquaired? False

# %% [markdown]
# ### Task 11: Watch key
#
# etcd3 api: https://python-etcd3.readthedocs.io/en/latest/usage.html
#
# This cell will lock this notebook on waiting
# After running it create a new notebook and try to add new user

# %%
def callb(cb):
    print(cb)

etcd.add_watch_callback(key='/users/test', callback=callb)
# Out:
# 5

# %%
etcd.put('/users/test', 'blazej')
# Out:
# <etcd3.watch.WatchResponse object at 0x7f65dd5bec50>
# header {
#   cluster_id: 17394822126184162018
#   member_id: 2713756945860001751
#   revision: 358045
#   raft_term: 3204
# }
# <etcd3.watch.WatchResponse object at 0x7f65dd5f7860>
# <etcd3.watch.WatchResponse object at 0x7f65dd5beb70>
# <etcd3.watch.WatchResponse object at 0x7f65dd5f74e0>
# <etcd3.watch.WatchResponse object at 0x7f65dc4dac50>
# <etcd3.watch.WatchResponse object at 0x7f65dd5f7748>
